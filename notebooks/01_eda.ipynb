# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("../data/sales_data.csv")

# Display first rows
print("First 5 Rows of Dataset:")
print(df.head())

print("\n")

# Create Revenue column
df["Revenue"] = df["Units_Sold"] * df["Unit_Price"]

# Display updated dataframe
print("Dataset with Revenue Column:")
print(df)

print("\n")

# Revenue grouped by category
category_revenue = df.groupby("Category")["Revenue"].sum()

print("Revenue by Category:")
print(category_revenue)

print("\n")

# Visualization
category_revenue.plot(kind="bar")

plt.title("Revenue by Product Category")
plt.xlabel("Category")
plt.ylabel("Revenue")

plt.show()

print("EDA workflow completed successfully")
# Out:
# First 5 Rows of Dataset:
#          Date   Product     Category  Units_Sold  Unit_Price
# 0  2026-01-01    Laptop  Electronics           5       12000
# 1  2026-01-02     Mouse  Accessories          20         250
# 2  2026-01-03  Keyboard  Accessories          15         500
# 3  2026-01-04   Monitor  Electronics           7        3500
# 4  2026-01-05     Phone  Electronics          10        8000
#
#
# Dataset with Revenue Column:
#          Date   Product     Category  Units_Sold  Unit_Price  Revenue
# 0  2026-01-01    Laptop  Electronics           5       12000    60000
# 1  2026-01-02     Mouse  Accessories          20         250     5000
# 2  2026-01-03  Keyboard  Accessories          15         500     7500
# 3  2026-01-04   Monitor  Electronics           7        3500    24500
# 4  2026-01-05     Phone  Electronics          10        8000    80000
# 5  2026-01-06    Laptop  Electronics           3       12000    36000
# 6  2026-01-07     Mouse  Accessories          25         250     6250
# 7  2026-01-08  Keyboard  Accessories          10         500     5000
# 8  2026-01-09   Monitor  Electronics           4        3500    14000
# 9  2026-01-10     Phone  Electronics           8        8000    64000
#
#
# Revenue by Category:
# Category
# Accessories     23750
# Electronics    278500
# Name: Revenue, dtype: int64
# EDA workflow completed successfully
