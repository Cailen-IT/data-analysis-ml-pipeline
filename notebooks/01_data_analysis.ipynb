# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("../data/sales_data.csv")

# Display first rows
print(df.head())

# Convert Date column
df["Date"] = pd.to_datetime(df["Date"])

# Feature Engineering
df["Revenue"] = df["Units_Sold"] * df["Unit_Price"]

# Display updated dataframe
print(df)

# Revenue grouped by category
category_revenue = df.groupby("Category")["Revenue"].sum()

print(category_revenue)

# Visualization
category_revenue.plot(kind="bar")

plt.title("Revenue by Category")
plt.xlabel("Category")
plt.ylabel("Revenue")

plt.show()

print("EDA workflow completed successfully")
# Out:
#          Date   Product     Category  Units_Sold  Unit_Price
# 0  2026-01-01    Laptop  Electronics           5       12000
# 1  2026-01-02     Mouse  Accessories          20         250
# 2  2026-01-03  Keyboard  Accessories          15         500
# 3  2026-01-04   Monitor  Electronics           7        3500
# 4  2026-01-05     Phone  Electronics          10        8000
#          Date               Product     Category  Units_Sold  Unit_Price  \
# 0  2026-01-01                Laptop  Electronics           5       12000
# 1  2026-01-02                 Mouse  Accessories          20         250
# 2  2026-01-03              Keyboard  Accessories          15         500
# 3  2026-01-04               Monitor  Electronics           7        3500
# 4  2026-01-05                 Phone  Electronics          10        8000
# 5  2026-01-06                Laptop  Electronics           3       12000
# 6  2026-01-07                 Mouse  Accessories          25         250
# 7  2026-01-08              Keyboard  Accessories          10         500
# 8  2026-01-09               Monitor  Electronics           4        3500
# 9  2026-01-10                 Phone  Electronics           8        8000
# 10 2026-01-11                Tablet  Electronics           6        6500
# 11 2026-01-12             USB Cable  Accessories          40         120
# 12 2026-01-13          Gaming Chair    Furniture           5        4500
# 13 2026-01-14             Desk Lamp    Furniture          12         700
# 14 2026-01-15                Router   Networking           9        1800
# 15 2026-01-16          External SSD      Storage           7        2200
# 16 2026-01-17  CailenTech Smart Hub  Electronics           4       15000
# 17 2026-01-18                Webcam  Accessories          14         950
# 18 2026-01-19           Office Desk    Furniture           3        5200
# 19 2026-01-20                Switch   Networking           6        3400
# 20 2026-01-21            Power Bank  Accessories          18         600
# 21 2026-01-22               Printer  Electronics           2        4800
# 22 2026-01-23             NAS Drive      Storage           5        7500
# 23 2026-01-24            Microphone  Accessories          11        1300
# 24 2026-01-25           Smart Watch  Electronics           9        5200
#
#     Revenue
# 0     60000
# 1      5000
# 2      7500
# 3     24500
# 4     80000
# 5     36000
# 6      6250
# 7      5000
# 8     14000
# 9     64000
# 10    39000
# 11     4800
# 12    22500
# 13     8400
# 14    16200
# 15    15400
# 16    60000
# 17    13300
# 18    15600
# 19    20400
# 20    10800
# 21     9600
# 22    37500
# 23    14300
# 24    46800
# Category
# Accessories     66950
# Electronics    433900
# Furniture       46500
# Networking      36600
# Storage         52900
# Name: Revenue, dtype: int64
# EDA workflow completed successfully
